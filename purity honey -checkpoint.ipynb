# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# %%
dataframe=pd.read_csv("honey-purity-prediction/Honey Purity prediction/honey purity dataset.csv")
dataframe
# Out:
#           CS  Density     WC    pH    EC      F      G Pollen_analysis  \
# 0       2.81     1.75  23.04  6.29  0.76  39.02  33.63       Blueberry
# 1       9.47     1.82  17.50  7.20  0.71  38.15  34.41         Alfalfa
# 2       4.61     1.84  23.72  7.31  0.80  27.47  34.36        Chestnut
# 3       1.77     1.40  16.61  4.01  0.78  31.52  28.15       Blueberry
# 4       6.11     1.25  19.63  4.82  0.90  29.65  42.52         Alfalfa
# ...      ...      ...    ...   ...   ...    ...    ...             ...
# 247898  1.98     1.29  17.90  4.82  0.89  36.10  34.69        Rosemary
# 247899  6.18     1.67  19.54  4.91  0.85  31.15  20.82          Acacia
# 247900  7.78     1.49  15.78  5.69  0.73  44.60  44.07        Chestnut
# 247901  5.78     1.74  14.96  6.81  0.83  47.19  37.79         Avocado
# 247902  8.96     1.86  18.62  6.89  0.86  25.94  42.88        Lavender
#
#         Viscosity  Purity   Price
# 0         4844.50    0.68  645.24
# 1         6689.02    0.89  385.85
# ...

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 247903 entries, 0 to 247902
# Data columns (total 11 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   CS               247903 non-null  float64
#  1   Density          247903 non-null  float64
#  2   WC               247903 non-null  float64
#  3   pH               247903 non-null  float64
#  4   EC               247903 non-null  float64
#  5   F                247903 non-null  float64
#  6   G                247903 non-null  float64
#  7   Pollen_analysis  247903 non-null  object
#  8   Viscosity        247903 non-null  float64
#  9   Purity           247903 non-null  float64
#  10  Price            247903 non-null  float64
# dtypes: float64(10), object(1)
# memory usage: 20.8+ MB

# %%
dataframe.describe()
# Out:
#                   CS        Density             WC             pH  \
# count  247903.000000  247903.000000  247903.000000  247903.000000
# mean        5.500259       1.535523      18.502625       4.996047
# std         2.593947       0.187824       3.748635       1.444060
# min         1.000000       1.210000      12.000000       2.500000
# 25%         3.260000       1.370000      15.260000       3.750000
# 50%         5.500000       1.540000      18.510000       4.990000
# 75%         7.740000       1.700000      21.750000       6.250000
# max        10.000000       1.860000      25.000000       7.500000
#
#                   EC              F              G      Viscosity  \
# count  247903.000000  247903.000000  247903.000000  247903.000000
# mean        0.799974      34.970573      32.501006    5752.893888
# std         0.057911       8.655898       7.226290    2455.739903
# min         0.700000      20.000000      20.000000    1500.050000
# ...

# %%
dataframe.isnull().sum()
# Out:
# CS                 0
# Density            0
# WC                 0
# pH                 0
# EC                 0
# F                  0
# G                  0
# Pollen_analysis    0
# Viscosity          0
# Purity             0
# Price              0
# dtype: int64

# %%
le=LabelEncoder()
dataframe["Pollen_analysis"]=le.fit_transform(dataframe["Pollen_analysis"])

# %%
dataframe
# Out:
#           CS  Density     WC    pH    EC      F      G  Pollen_analysis  \
# 0       2.81     1.75  23.04  6.29  0.76  39.02  33.63                3
# 1       9.47     1.82  17.50  7.20  0.71  38.15  34.41                1
# 2       4.61     1.84  23.72  7.31  0.80  27.47  34.36                6
# 3       1.77     1.40  16.61  4.01  0.78  31.52  28.15                3
# 4       6.11     1.25  19.63  4.82  0.90  29.65  42.52                1
# ...      ...      ...    ...   ...   ...    ...    ...              ...
# 247898  1.98     1.29  17.90  4.82  0.89  36.10  34.69               13
# 247899  6.18     1.67  19.54  4.91  0.85  31.15  20.82                0
# 247900  7.78     1.49  15.78  5.69  0.73  44.60  44.07                6
# 247901  5.78     1.74  14.96  6.81  0.83  47.19  37.79                2
# 247902  8.96     1.86  18.62  6.89  0.86  25.94  42.88               10
#
#         Viscosity  Purity   Price
# 0         4844.50    0.68  645.24
# ...

# %%
dataframe["Pollen_analysis"].nunique()
# Out:
# 19

# %%
X=dataframe[['CS','Density','WC','pH','EC','F','G','Pollen_analysis','Viscosity','Price']]
y=dataframe["Purity"]
print(X,y)
# Out:
#           CS  Density     WC    pH    EC      F      G  Pollen_analysis  \
# 0       2.81     1.75  23.04  6.29  0.76  39.02  33.63                3
# 1       9.47     1.82  17.50  7.20  0.71  38.15  34.41                1
# 2       4.61     1.84  23.72  7.31  0.80  27.47  34.36                6
# 3       1.77     1.40  16.61  4.01  0.78  31.52  28.15                3
# 4       6.11     1.25  19.63  4.82  0.90  29.65  42.52                1
# ...      ...      ...    ...   ...   ...    ...    ...              ...
# 247898  1.98     1.29  17.90  4.82  0.89  36.10  34.69               13
# 247899  6.18     1.67  19.54  4.91  0.85  31.15  20.82                0
# 247900  7.78     1.49  15.78  5.69  0.73  44.60  44.07                6
# 247901  5.78     1.74  14.96  6.81  0.83  47.19  37.79                2
# 247902  8.96     1.86  18.62  6.89  0.86  25.94  42.88               10
#
#         Viscosity   Price
# 0         4844.50  645.24
# 1         6689.02  385.85
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
X_train
# Out:
#           CS  Density     WC    pH    EC      F      G  Pollen_analysis  \
# 235088  1.54     1.67  22.88  3.80  0.82  38.58  36.52                0
# 184437  7.27     1.65  22.23  7.09  0.86  36.53  20.64                9
# 117929  6.85     1.81  12.43  6.57  0.83  22.24  20.07               18
# 153750  4.63     1.26  15.87  3.36  0.76  43.23  29.25                4
# 69148   1.11     1.42  14.89  6.72  0.90  48.87  44.60                7
# ...      ...      ...    ...   ...   ...    ...    ...              ...
# 119879  2.43     1.68  21.70  6.95  0.74  20.18  22.15                8
# 103694  8.07     1.67  19.84  4.06  0.83  46.96  37.37                6
# 131932  2.91     1.62  20.79  2.68  0.70  20.01  44.90               15
# 146867  8.46     1.78  15.13  6.29  0.78  28.92  29.97                3
# 121958  6.61     1.31  16.05  6.74  0.84  24.14  24.58               15
#
#         Viscosity   Price
# 235088    7171.60  457.47
# 184437    5202.24  608.32
# ...

# %%
from sklearn.ensemble import RandomForestRegressor,RandomForestClassifier

# %%
model1=RandomForestRegressor()
model2=RandomForestClassifier()
model1
# Out:
# RandomForestRegressor()

# %%
model2
# Out:
# RandomForestClassifier()

# %%
model1.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %%
y_predict=model1.predict(X_test)
y_predict
# Out:
# array([0.7107, 0.99  , 0.84  , ..., 0.89  , 0.66  , 0.8894])

# %%
y_test
# Out:
# 29002     0.64
# 13563     0.99
# 12445     0.84
# 233689    0.63
# 52643     0.82
#           ...
# 114581    0.63
# 76348     1.00
# 29770     0.89
# 105342    0.66
# 74882     0.89
# Name: Purity, Length: 81808, dtype: float64

# %%
from sklearn.metrics import r2_score

# %%
r2s=r2_score

# %%
r2s(y_predict,y_test)
# Out:
# 0.9939693279305812

# %%
plt.scatter(y_predict,y_test)

# %%
residuals = y_test - y_predict

plt.figure(figsize=(8,6))
sns.histplot(residuals, bins=30, kde=True)
plt.axvline(0, color='red', linestyle='--')  # Zero residual line
plt.xlabel("Residual (Error)")
plt.ylabel("Frequency")
plt.title("Residual Distribution")
plt.show()

# %%
from sklearn.ensemble import RandomForestRegressor

model = RandomForestRegressor(
    n_estimators=100,    # Reduce the number of trees
    max_depth=10,        # Limit tree depth to prevent overfitting
    min_samples_split=5, # Require at least 5 samples to split a node
    random_state=42
)
model
# Out:
# RandomForestRegressor(max_depth=10, min_samples_split=5, random_state=42)

# %%
model.fit(X_train,y_train)
# Out:
# RandomForestRegressor(max_depth=10, min_samples_split=5, random_state=42)

# %%
y_p=model.predict(X_test)
y_p
# Out:
# array([0.76755329, 0.98174014, 0.82442932, ..., 0.86809233, 0.66136121,
#        0.87509018])

# %%
y_test
# Out:
# 29002     0.64
# 13563     0.99
# 12445     0.84
# 233689    0.63
# 52643     0.82
#           ...
# 114581    0.63
# 76348     1.00
# 29770     0.89
# 105342    0.66
# 74882     0.89
# Name: Purity, Length: 81808, dtype: float64

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x=y_test, y=y_predict, alpha=0.6)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], color='red', linestyle='--')  # Perfect fit line
plt.xlabel("Actual Purity")
plt.ylabel("Predicted Purity")
plt.title(f"Actual vs Predicted (R² = {r2_score(y_test, y_predict):.2f})")
plt.show()

# %%
plt.scatter(y_test,y_p)

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x=y_test, y=y_p, alpha=0.6)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], color='red', linestyle='--')  # Perfect fit line
plt.xlabel("Actual Purity")
plt.ylabel("Predicted Purity")
plt.title(f"Actual vs Predicted (R² = {r2_score(y_test, y_p):.2f})")
plt.show()
